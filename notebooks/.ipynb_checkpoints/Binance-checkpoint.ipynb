# %%
import requests

# %% [markdown]
# # **바이넨스** API 사용법
#
# - 본 문서를 사용함에 있어서 발생하는 문제는 책임지지 않습니다.
#
# - 바이넨스 API 공식 문서는 [다음 링크](https://github.com/binance-exchange/binance-official-api-docs/blob/master/rest-api.md)를 참고하시기 바랍니다.
#
# ## 목차
#
# 1. Why Binance?
#
# 2. How To Create Account?
#
# 3. Using API
#
#     - Encrypt Parameters using `hmac`
#
#     - Let's Make a Request Using `Requests` Module
#
# ## 1. Why **Binance**?
#
# - 거래량 1위 (유동성이 많음)
#
# - 다양한 암호화폐를 지원함
#
# ## 2. How To Create Account?
#
# - 이메일 가입 후 Google Authenticator로 OTP 설정하면 끝.
#
# - 원화 입금이 안됨, 한국 거래소로 입금 후 비트코인을 통해서 거래 가능.
#
#     - `USDT`를 사용해보는 것도 고려 가능한 방법
#
# - API 같은 경우에는 My Account 페이지에 가면 두개로 발급 가능
#
#     - apiKey: API 전송을 위한 키
#
#     - secretKey: 추후에 진행할 암호화를 통해서 전송할 때 사용할 키 (HMAC.SHA256을 사용하여 암호화 할때 사용할 키)
#
#         - 주문을 할 때 HMAC SHA256을 사용하여 암호화하는 과정을 거침.
#
# ## 3. Using API
#
# ### Requirements
#
# - Requests
#
#     - `curl` 을 통해서 GET Request를 날려도 됨.
#
# - `conf/config.ini` 쪽에 관련 API 키를 정리해 놓을 것
#
# ```ini
# [BINANCE]
# apiKey =
# secretKey =
# ```
#
# ### 1. Ping을 사용하여 Connectivity Test 하기

# %%
req = requests.get('https://binance.com/api/v1/ping')

# %% [markdown]
# - HTTP `4XX` 코드는 요청에 오류가 있을 때 표시됩니다. 이 경우에는 보내는 사람한테 오류가 있는 경우에 발생합니다.
#
# - HTTP `429` 코도는 Reqeust Rate Limit 을 넘었을 경우에 발생합니다.
#
#     - Request Rate Limit 같은 경우에는 `/api/v1/exchangeInfo` 요청을 보냈을 경우에 확인이 가능합니다.
#
# - HTTP `418` 코드는 앞서 설명한 HTTP `429` 코드를 계속해서 요청했을 때 자동차단되어 밴이 발생하였을 때 표시되는 코드입니다.
#
# - HTTP `5XX` 코드 같은 경우에는 바이넨스 서버 측에서 오류를 보낸 경우에 표시됩니다. (It is important to NOT treat this as a failure operation; the execution status is UNKNOWN and could have been a success.)
#
# - 모든 엔드포인트는 다음과 같읕 에러를 리턴할 수 있습니다, 에러는 다른 도큐멘트에 만들어 놓았습니다.
#
# ```json
# {
#   "code": -1121,
#   "msg": "Invalid symbol."
# }
# ```

# %%
req.status_code # Status Code 조회
# Out:
# 200

# %% [markdown]
# ### `Request Rate Limit` 확인하기

# %%
req = requests.get('https://binance.com/api/v1/exchangeInfo')

# %%
req.json()['rateLimits'] # rateLimits 항목에 있음.
# Out:
# [{'rateLimitType': 'REQUEST_WEIGHT',
#   'interval': 'MINUTE',
#   'intervalNum': 1,
#   'limit': 1200},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'SECOND',
#   'intervalNum': 1,
#   'limit': 10},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'DAY',
#   'intervalNum': 1,
#   'limit': 100000}]

# %% [markdown]
# ### 거래 가능한 `Coin Symbol` 확인하기

# %%
req.json()['symbols'][0]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00000000',
#    'maxPrice': '0.00000000',
#    'tickSize': '0.00000100'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '10',
#    'multiplierDown': '0.1',
#    'avgPriceMins': 5},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00100000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00100000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '0.00100000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}

# %%
num_of_symbols = len(req.json()['symbols'])
print("심볼 총합 :", num_of_symbols)
# Out:
# 심볼 총합 : 431

# %%
# 모든 코인에 대해서 표시함, 'TRADING' or 'BREAK' 으로 표시됨.
for i in range(num_of_symbols):
    print("%s|%s|%s" % (req.json()['symbols'][i]['symbol'], req.json()['symbols'][i]['status'], req.json()['symbols'][i]['baseAsset']))
# Out:
# ETHBTC|TRADING|ETH
# LTCBTC|TRADING|LTC
# BNBBTC|TRADING|BNB
# NEOBTC|TRADING|NEO
# QTUMETH|TRADING|QTUM
# EOSETH|TRADING|EOS
# SNTETH|TRADING|SNT
# BNTETH|TRADING|BNT
# BCCBTC|BREAK|BCC
# GASBTC|TRADING|GAS
# BNBETH|TRADING|BNB
# BTCUSDT|TRADING|BTC
# ETHUSDT|TRADING|ETH
# HSRBTC|BREAK|HSR
# OAXETH|TRADING|OAX
# DNTETH|TRADING|DNT
# MCOETH|TRADING|MCO
# ICNETH|BREAK|ICN
# MCOBTC|TRADING|MCO
# WTCBTC|TRADING|WTC
# WTCETH|TRADING|WTC
# LRCBTC|TRADING|LRC
# LRCETH|TRADING|LRC
# QTUMBTC|TRADING|QTUM
# YOYOBTC|TRADING|YOYO
# OMGBTC|TRADING|OMG
# OMGETH|TRADING|OMG
# ZRXBTC|TRADING|ZRX
# ZRXETH|TRADING|ZRX
# STRATBTC|TRADING|STRAT
# STRATETH|TRADING|STRAT
# SNGLSBTC|TRADING|SNGLS
# SNGLSETH|TRADING|SNGLS
# BQXBTC|TRADING|BQX
# BQXETH|TRADING|BQX
# KNCBTC|TRADING|KNC
# KNCETH|TRADING|KNC
# FUNBTC|TRADING|FUN
# FUNETH|TRADING|FUN
# SNMBTC|TRADING|SNM
# SNMETH|TRADING|SNM
# NEOETH|TRADING|NEO
# IOTABTC|TRADING|IOTA
# IOTAETH|TRADING|IOTA
# LINKBTC|TRADING|LINK
# LINKETH|TRADING|LINK
# XVGBTC|TRADING|XVG
# XVGETH|TRADING|XVG
# SALTBTC|TRADING|SALT
# SALTETH|TRADING|SALT
# MDABTC|TRADING|MDA
# QSPETH|TRADING|QSP
# QSPBNB|TRADING|QSP
# BTSBTC|TRADING|BTS
# BTSETH|TRADING|BTS
# BTSBNB|TRADING|BTS
# XZCBTC|TRADING|XZC
# XZCETH|TRADING|XZC
# XZCBNB|TRADING|XZC
# LSKBTC|TRADING|LSK
# LSKETH|TRADING|LSK
# LSKBNB|TRADING|LSK
# TNTBTC|TRADING|TNT
# TNTETH|TRADING|TNT
# FUELBTC|TRADING|FUEL
# FUELETH|TRADING|FUEL
# MANABTC|TRADING|MANA
# MANAETH|TRADING|MANA
# BCDBTC|TRADING|BCD
# BCDETH|TRADING|BCD
# DGDBTC|TRADING|DGD
# DGDETH|TRADING|DGD
# IOTABNB|TRADING|IOTA
# ADXBTC|TRADING|ADX
# ADXETH|TRADING|ADX
# ADXBNB|TRADING|ADX
# ADABTC|TRADING|ADA
# ADAETH|TRADING|ADA
# PPTBTC|TRADING|PPT
# PPTETH|TRADING|PPT
# CMTBTC|TRADING|CMT
# CMTETH|TRADING|CMT
# CMTBNB|TRADING|CMT
# XLMBTC|TRADING|XLM
# XLMETH|TRADING|XLM
# XLMBNB|TRADING|XLM
# CNDBTC|TRADING|CND
# CNDETH|TRADING|CND
# CNDBNB|TRADING|CND
# LENDBTC|TRADING|LEND
# LENDETH|TRADING|LEND
# WABIBTC|TRADING|WABI
# WABIETH|TRADING|WABI
# WABIBNB|TRADING|WABI
# LTCETH|TRADING|LTC
# LTCUSDT|TRADING|LTC
# LTCBNB|TRADING|LTC
# TNBBTC|TRADING|TNB
# TNBETH|TRADING|TNB
# WAVESBTC|TRADING|WAVES
# WAVESETH|TRADING|WAVES
# WAVESBNB|TRADING|WAVES
# GTOBTC|TRADING|GTO
# GTOETH|TRADING|GTO
# GTOBNB|TRADING|GTO
# ICXBTC|TRADING|ICX
# ICXETH|TRADING|ICX
# ICXBNB|TRADING|ICX
# OSTBTC|TRADING|OST
# OSTETH|TRADING|OST
# OSTBNB|TRADING|OST
# ELFBTC|TRADING|ELF
# ELFETH|TRADING|ELF
# AIONBTC|TRADING|AION
# AIONETH|TRADING|AION
# AIONBNB|TRADING|AION
# NEBLBTC|TRADING|NEBL
# NEBLETH|TRADING|NEBL
# NEBLBNB|TRADING|NEBL
# BRDBTC|TRADING|BRD
# BRDETH|TRADING|BRD
# BRDBNB|TRADING|BRD
# MCOBNB|TRADING|MCO
# EDOBTC|TRADING|EDO
# EDOETH|TRADING|EDO
# WINGSBTC|TRADING|WINGS
# WINGSETH|TRADING|WINGS
# NAVBTC|TRADING|NAV
# NAVETH|TRADING|NAV
# NAVBNB|TRADING|NAV
# LUNBTC|TRADING|LUN
# LUNETH|TRADING|LUN
# TRIGBTC|BREAK|TRIG
# TRIGETH|BREAK|TRIG
# TRIGBNB|BREAK|TRIG
# APPCBTC|TRADING|APPC
# APPCETH|TRADING|APPC
# APPCBNB|TRADING|APPC
# VIBEBTC|TRADING|VIBE
# VIBEETH|TRADING|VIBE
# RLCBTC|TRADING|RLC
# RLCETH|TRADING|RLC
# RLCBNB|TRADING|RLC
# INSBTC|TRADING|INS
# INSETH|TRADING|INS
# PIVXBTC|TRADING|PIVX
# PIVXETH|TRADING|PIVX
# PIVXBNB|TRADING|PIVX
# IOSTBTC|TRADING|IOST
# IOSTETH|TRADING|IOST
# CHATBTC|BREAK|CHAT
# CHATETH|BREAK|CHAT
# STEEMBTC|TRADING|STEEM
# STEEMETH|TRADING|STEEM
# STEEMBNB|TRADING|STEEM
# NANOBTC|TRADING|NANO
# NANOETH|TRADING|NANO
# NANOBNB|TRADING|NANO
# VIABTC|TRADING|VIA
# VIAETH|TRADING|VIA
# VIABNB|TRADING|VIA
# BLZBTC|TRADING|BLZ
# BLZETH|TRADING|BLZ
# BLZBNB|TRADING|BLZ
# AEBTC|TRADING|AE
# AEETH|TRADING|AE
# AEBNB|TRADING|AE
# RPXBTC|BREAK|RPX
# RPXETH|BREAK|RPX
# RPXBNB|BREAK|RPX
# NCASHBTC|TRADING|NCASH
# NCASHETH|TRADING|NCASH
# NCASHBNB|TRADING|NCASH
# POABTC|TRADING|POA
# POAETH|TRADING|POA
# POABNB|TRADING|POA
# ZILBTC|TRADING|ZIL
# ZILETH|TRADING|ZIL
# ZILBNB|TRADING|ZIL
# ONTBTC|TRADING|ONT
# ONTETH|TRADING|ONT
# ONTBNB|TRADING|ONT
# STORMBTC|TRADING|STORM
# STORMETH|TRADING|STORM
# STORMBNB|TRADING|STORM
# QTUMBNB|TRADING|QTUM
# QTUMUSDT|TRADING|QTUM
# XEMBTC|TRADING|XEM
# XEMETH|TRADING|XEM
# XEMBNB|TRADING|XEM
# WANBTC|TRADING|WAN
# WANETH|TRADING|WAN
# WANBNB|TRADING|WAN
# WPRBTC|TRADING|WPR
# WPRETH|TRADING|WPR
# QLCBTC|TRADING|QLC
# QLCETH|TRADING|QLC
# SYSBTC|TRADING|SYS
# SYSETH|TRADING|SYS
# SYSBNB|TRADING|SYS
# QLCBNB|TRADING|QLC
# GRSBTC|TRADING|GRS
# GRSETH|TRADING|GRS
# ADAUSDT|TRADING|ADA
# ADABNB|TRADING|ADA
# CLOAKBTC|TRADING|CLOAK
# CLOAKETH|TRADING|CLOAK
# GNTBTC|TRADING|GNT
# GNTETH|TRADING|GNT
# GNTBNB|TRADING|GNT
# LOOMBTC|TRADING|LOOM
# LOOMETH|TRADING|LOOM
# LOOMBNB|TRADING|LOOM
# XRPUSDT|TRADING|XRP
# BCNBTC|BREAK|BCN
# BCNETH|BREAK|BCN
# BCNBNB|BREAK|BCN
# REPBTC|TRADING|REP
# REPETH|TRADING|REP
# REPBNB|TRADING|REP
# TUSDBTC|TRADING|TUSD
# TUSDETH|TRADING|TUSD
# TUSDBNB|TRADING|TUSD
# ZENBTC|TRADING|ZEN
# ZENETH|TRADING|ZEN
# ZENBNB|TRADING|ZEN
# SKYBTC|TRADING|SKY
# SKYETH|TRADING|SKY
# SKYBNB|TRADING|SKY
# EOSUSDT|TRADING|EOS
# EOSBNB|TRADING|EOS
# CVCBTC|TRADING|CVC
# CVCETH|TRADING|CVC
# CVCBNB|TRADING|CVC
# THETABTC|TRADING|THETA
# THETAETH|TRADING|THETA
# THETABNB|TRADING|THETA
# XRPBNB|TRADING|XRP
# TUSDUSDT|TRADING|TUSD
# IOTAUSDT|TRADING|IOTA
# XLMUSDT|TRADING|XLM
# IOTXBTC|TRADING|IOTX
# IOTXETH|TRADING|IOTX
# QKCBTC|TRADING|QKC
# QKCETH|TRADING|QKC
# AGIBTC|TRADING|AGI
# AGIETH|TRADING|AGI
# AGIBNB|TRADING|AGI
# NXSBTC|TRADING|NXS
# NXSETH|TRADING|NXS
# NXSBNB|TRADING|NXS
# ENJBNB|TRADING|ENJ
# DATABTC|TRADING|DATA
# DATAETH|TRADING|DATA
# ONTUSDT|TRADING|ONT
# TRXBNB|TRADING|TRX
# TRXUSDT|TRADING|TRX
# ETCUSDT|TRADING|ETC
# ETCBNB|TRADING|ETC
# ICXUSDT|TRADING|ICX
# SCBTC|TRADING|SC
# SCETH|TRADING|SC
# SCBNB|TRADING|SC
# NPXSBTC|TRADING|NPXS
# NPXSETH|TRADING|NPXS
# VENUSDT|BREAK|VEN
# KEYBTC|TRADING|KEY
# KEYETH|TRADING|KEY
# NASBTC|TRADING|NAS
# NASETH|TRADING|NAS
# NASBNB|TRADING|NAS
# MFTBTC|TRADING|MFT
# MFTETH|TRADING|MFT
# MFTBNB|TRADING|MFT
# DENTBTC|TRADING|DENT
# DENTETH|TRADING|DENT
# ARDRBTC|TRADING|ARDR
# ARDRETH|TRADING|ARDR
# ARDRBNB|TRADING|ARDR
# NULSUSDT|TRADING|NULS
# HOTBTC|TRADING|HOT
# HOTETH|TRADING|HOT
# VETBTC|TRADING|VET
# VETETH|TRADING|VET
# VETUSDT|TRADING|VET
# VETBNB|TRADING|VET
# DOCKBTC|TRADING|DOCK
# DOCKETH|TRADING|DOCK
# POLYBTC|TRADING|POLY
# POLYBNB|TRADING|POLY
# PHXBTC|TRADING|PHX
# PHXETH|TRADING|PHX
# PHXBNB|TRADING|PHX
# HCBTC|TRADING|HC
# HCETH|TRADING|HC
# GOBTC|TRADING|GO
# GOBNB|TRADING|GO
# PAXBTC|BREAK|PAX
# PAXBNB|BREAK|PAX
# PAXUSDT|TRADING|PAX
# PAXETH|BREAK|PAX
# RVNBTC|TRADING|RVN
# RVNBNB|TRADING|RVN
# DCRBTC|TRADING|DCR
# DCRBNB|TRADING|DCR
# USDCBNB|BREAK|USDC
# USDCBTC|BREAK|USDC
# MITHBTC|TRADING|MITH
# MITHBNB|TRADING|MITH
# BCHABCBTC|TRADING|BCHABC
# BCHSVBTC|TRADING|BCHSV
# BCHABCUSDT|TRADING|BCHABC
# BCHSVUSDT|TRADING|BCHSV
# BNBPAX|TRADING|BNB
# BTCPAX|TRADING|BTC
# ETHPAX|TRADING|ETH
# XRPPAX|TRADING|XRP
# EOSPAX|TRADING|EOS
# XLMPAX|TRADING|XLM
# RENBTC|TRADING|REN
# RENBNB|TRADING|REN
# XRPTUSD|TRADING|XRP
# EOSTUSD|TRADING|EOS
# XLMTUSD|TRADING|XLM
# BNBUSDC|TRADING|BNB
# BTCUSDC|TRADING|BTC
# ETHUSDC|TRADING|ETH
# XRPUSDC|TRADING|XRP
# EOSUSDC|TRADING|EOS
# XLMUSDC|TRADING|XLM
# USDCUSDT|TRADING|USDC
# ADATUSD|TRADING|ADA
# TRXTUSD|TRADING|TRX
# NEOTUSD|TRADING|NEO
# TRXXRP|TRADING|TRX
# XZCXRP|TRADING|XZC

# %% [markdown]
# ### 바이넨스 코인 Order Book 확인하기
#
# - URL: `GET /api/v1/depth`
#
# - 파라메터
#
# **Weight**: 가중치에 따라서 Weight을 조정할 것
#
# Limit|Weight
# ---|---
# 5, 10, 20, 50, 100 |1
# 500|5
# 1000|10
#
# **Parameters**:
#
# 이름|타입|필수|설명
# ---|---|---|---
# symbol|문자열|O|앞서 봤던 코인 심볼
# limit|숫자|X|디폴트 100; 최대 1000 (정상 리밋: [5, 10, 20, 50, 100, 500, 1000])

# %%
param = {
    "symbol": "BTCUSDC"
}

# %%
req = requests.get('https://binance.com/api/v1/depth', params=param)

# %%
req.status_code
# Out:
# 200

# %%
req.json()
# Out:
# {'lastUpdateId': 1702431,
#  'bids': [['3876.86000000', '0.00746400', []],
#   ['3876.83000000', '10.00000000', []],
#   ['3875.09000000', '0.16507900', []],
#   ['3869.02000000', '0.13116000', []],
#   ['3868.42000000', '0.12889100', []],
#   ['3868.41000000', '0.14957500', []],
#   ['3868.15000000', '0.00490400', []],
#   ['3853.86000000', '0.00260800', []],
#   ['3852.02000000', '0.60000000', []],
#   ['3852.01000000', '0.00500600', []],
#   ['3851.93000000', '0.00260900', []],
#   ['3851.38000000', '0.00392000', []],
#   ['3850.00000000', '3.06771100', []],
#   ['3848.08000000', '0.00261200', []],
#   ['3846.15000000', '0.00261300', []],
#   ['3844.23000000', '0.00261400', []],
#   ['3842.31000000', '0.00261600', []],
#   ['3840.39000000', '0.00261700', []],
#   ['3840.00000000', '0.05800000', []],
#   ['3837.47000000', '0.00550000', []],
#   ['3836.56000000', '0.00262000', []],
#   ['3832.74000000', '0.00262200', []],
#   ['3830.83000000', '0.00262300', []],
#   ['3828.92000000', '0.00262500', []],
#   ['3827.02000000', '0.00262600', []],
#   ['3827.00000000', '1.00000000', []],
#   ['3823.21000000', '0.00262900', []],
#   ['3819.42000000', '0.00263100', []],
#   ['3814.00000000', '0.02007600', []],
#   ['3812.87000000', '0.00396000', []],
#   ['3810.00000000', '1.45606700', []],
#   ['3807.51000000', '0.40483200', []],
#   ['3802.00000000', '0.01033100', []],
#   ['3800.00000000', '2.67702900', []],
#   ['3780.00000000', '0.07345900', []],
#   ['3777.00000000', '1.00000000', []],
#   ['3776.54000000', '0.20000000', []],
#   ['3774.74000000', '0.00400000', []],
#   ['3768.00000000', '0.02653900', []],
#   ['3766.54000000', '0.25000000', []],
#   ['3765.00000000', '0.02656000', []],
#   ['3763.36000000', '0.00267000', []],
#   ['3760.00000000', '0.94026000', []],
#   ['3757.00000000', '3.01265400', []],
#   ['3756.54000000', '0.07098300', []],
#   ['3755.16000000', '0.07988900', []],
#   ['3754.00000000', '4.53917200', []],
#   ['3753.21000000', '0.20231900', []],
#   ['3752.55000000', '0.12300600', []],
#   ['3750.00000000', '1.40483700', []],
#   ['3745.00000000', '0.07338100', []],
#   ['3743.21000000', '0.25000000', []],
#   ['3743.00000000', '0.02671600', []],
#   ['3740.00000000', '0.16594100', []],
#   ['3990.00000000', '0.05395600', []],
#   ['3992.00000000', '0.06318000', []],
#   ['3992.17000000', '0.02238700', []],
#   ['3997.54000000', '0.00595300', []],
#   ['3998.00000000', '0.20138200', []],
#   ['3999.00000000', '2.55226200', []],
#   ['4000.00000000', '2.37272200', []],
#   ['4001.00000000', '0.11248400', []],
#   ['4010.00000000', '0.06322100', []],
#   ['4011.00000000', '0.01000000', []],
#   ['4016.06000000', '1.44880800', []],
#   ['4018.00000000', '0.01000000', []],
#   ['4030.00000000', '3.04145500', []],
#   ['4030.67000000', '0.00893100', []],
#   ['4035.00000000', '0.01000000', []],
#   ['4050.00000000', '1.34510700', []],
#   ['4058.00000000', '0.01000000', []],
#   ['4060.00000000', '0.02463000', []],
#   ['4067.31000000', '0.06199000', []],
#   ['4069.84000000', '1.00000000', []],
#   ['4085.00000000', '0.36298000', []],
#   ['4085.83000000', '0.01185600', []],
#   ['4089.00000000', '17.19000000', []],
#   ['4090.00000000', '0.01000000', []],
#   ['4090.62000000', '0.01106200', []],
#   ['4094.34000000', '0.02641700', []],
#   ['4095.00000000', '0.17882000', []],
#   ['4100.00000000', '0.29226900', []],
#   ['4102.85000000', '0.01064200', []],
#   ['4105.00000000', '0.06090100', []],
#   ['4109.61000000', '0.00294200', []],
#   ['4111.00000000', '0.01000000', []],
#   ['4112.49000000', '0.00496000', []],
#   ['4115.00000000', '0.03340400', []],
#   ['4120.00000000', '0.02427100', []],
#   ['4134.62000000', '0.02000000', []],
#   ['4137.31000000', '0.06199100', []],
#   ['4144.00000000', '1.05959000', []],
#   ['4150.00000000', '4.83699800', []],
#   ['4160.69000000', '0.04929000', []],
#   ['4163.22000000', '0.02293000', []],
#   ['4170.00000000', '0.18526300', []],
#   ['4176.00000000', '0.03155900', []],
#   ['4177.98000000', '0.24413000', []],
#   ['4178.00000000', '0.20000000', []],
#   ['4180.00000000', '0.02392300', []],
#   ['4185.00000000', '0.02677000', []],
#   ['4190.00000000', '0.01000000', []],
#   ['4191.80000000', '4.25556900', []],
#   ['4194.16000000', '0.13785400', []],
#   ['4199.00000000', '3.94817200', []],
#   ['4200.00000000', '1.06792300', []],
#   ['4201.00000000', '0.01308900', []],
#   ['4205.00000000', '0.11890600', []],
#   ['4215.00000000', '0.00411900', []],
#   ['4222.00000000', '0.50868900', []],
#   ['4222.02000000', '0.00475800', []],
#   ['4225.29000000', '0.17454800', []],
#   ['4226.43000000', '0.01629800', []],
#   ['4226.80000000', '0.00473600', []],
#   ['4228.00000000', '0.20000000', []],
#   ['4234.00000000', '0.63524900', []],
#   ['4234.62000000', '0.02000000', []],
#   ['4235.00000000', '0.20305900', []],
#   ['4236.00000000', '0.01227500', []],
#   ['4240.00000000', '0.02358400', []],
#   ['4249.49000000', '0.05269500', []],
#   ['4250.00000000', '0.09542700', []],
#   ['4260.69000000', '0.04929100', []],
#   ['4268.00000000', '0.00835300', []],
#   ['4274.00000000', '0.00550000', []]]}

# %% [markdown]
# ### 최근 거래 리스트
#
# - URL: `GET /api/v1/trades`

# %%
req = requests.get('https://binance.com/api/v1/trades', params=param)

# %%
req.status_code
# Out:
# 200
